# %% [markdown]
# # **Data collection**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

# %%
df=pd.read_csv('/content/Housing.csv')

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0                no             yes        2      yes        furnished
# 1                no             yes        3       no        furnished
# 2                no              no        2      yes   semi-furnished
# 3                no             yes        3      yes        furnished
# 4                no             yes        2       no        furnished
# ..              ...             ...      ...      ...              ...
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished
#
# [545 rows x 13 columns]

# %%
df.head(10)
# Out:
#       price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000   7420         4          2        3      yes        no       no
# 1  12250000   8960         4          4        4      yes        no       no
# 2  12250000   9960         3          2        2      yes        no      yes
# 3  12215000   7500         4          2        2      yes        no      yes
# 4  11410000   7420         4          1        2      yes       yes      yes
# 5  10850000   7500         3          3        1      yes        no      yes
# 6  10150000   8580         4          3        4      yes        no       no
# 7  10150000  16200         5          3        2      yes        no       no
# 8   9870000   8100         4          1        2      yes       yes      yes
# 9   9800000   5750         3          2        4      yes       yes       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished
# 5              no             yes        2      yes   semi-furnished
# 6              no             yes        2      yes   semi-furnished
# 7              no              no        0       no      unfurnished
# 8              no             yes        2      yes        furnished
# 9              no             yes        1      yes      unfurnished

# %% [markdown]
# # **Data Exploration and Cleaning**

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
df.dtypes
# Out:
# price                int64
# area                 int64
# bedrooms             int64
# bathrooms            int64
# stories              int64
# mainroad            object
# guestroom           object
# basement            object
# hotwaterheating     object
# airconditioning     object
# parking              int64
# prefarea            object
# furnishingstatus    object
# dtype: object

# %%
df.shape
# Out:
# (545, 13)

# %%
selected=['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'parking']

# %%
plt.figure(figsize=(12, 8))  # Set the figure size
num_rows = 5  # Increased num_rows to 5 to accommodate all 13 plots
num_cols = 3

for i, column in enumerate(selected, 1):
    plt.subplot(num_rows, num_cols, i)  # Update subplot grid
    sns.boxplot(y=df[column],color='lightblue')
    plt.title(f'Box Plot of {column}')

plt.tight_layout()  # Adjust subplot parameters for a tight layout
plt.show()

# %%
sns.boxplot(df['price'])
# Out:
# <Axes: ylabel='price'>

# %%
q1 = df['price'].quantile(0.25)
q3 = df['price'].quantile(0.75)
iqr = q3-q1
lower_lim = q1 - 1.5*iqr
upper_lim = q3 + 1.5*iqr

# %%
q1,q3,iqr
# Out:
# (3430000.0, 5740000.0, 2310000.0)

# %%
lower_lim,upper_lim
# Out:
# (-35000.0, 9205000.0)

# %%
out = df[(df['price'] > upper_lim) | (df['price'] < lower_lim)]

# %%
out
# Out:
#        price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0   13300000   7420         4          2        3      yes        no       no
# 1   12250000   8960         4          4        4      yes        no       no
# 2   12250000   9960         3          2        2      yes        no      yes
# 3   12215000   7500         4          2        2      yes        no      yes
# 4   11410000   7420         4          1        2      yes       yes      yes
# 5   10850000   7500         3          3        1      yes        no      yes
# 6   10150000   8580         4          3        4      yes        no       no
# 7   10150000  16200         5          3        2      yes        no       no
# 8    9870000   8100         4          1        2      yes       yes      yes
# 9    9800000   5750         3          2        4      yes       yes       no
# 10   9800000  13200         3          1        2      yes        no      yes
# 11   9681000   6000         4          3        2      yes       yes      yes
# 12   9310000   6550         4          2        2      yes        no       no
# 13   9240000   3500         4          2        2      yes        no       no
# 14   9240000   7800         3          2        2      yes        no       no
#
#    hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0               no             yes        2      yes        furnished
# 1               no             yes        3       no        furnished
# 2               no              no        2      yes   semi-furnished
# 3               no             yes        3      yes        furnished
# 4               no             yes        2       no        furnished
# 5               no             yes        2      yes   semi-furnished
# 6               no             yes        2      yes   semi-furnished
# 7               no              no        0       no      unfurnished
# 8               no             yes        2      yes        furnished
# 9               no             yes        1      yes      unfurnished
# 10              no             yes        2      yes        furnished
# 11             yes              no        2       no   semi-furnished
# 12              no             yes        1      yes   semi-furnished
# 13             yes              no        2       no        furnished
# 14              no              no        0      yes   semi-furnished

# %%
df.loc[df['price'] > upper_lim, 'price'] = upper_lim
df.loc[df['price'] < lower_lim, 'price'] = lower_lim

# %%
sns.boxplot(df['price'])
# Out:
# <Axes: ylabel='price'>

# %%
sns.boxplot(df['area'])
# Out:
# <Axes: ylabel='area'>

# %%
q1 = df['area'].quantile(0.25)
q3 = df['area'].quantile(0.75)
iqr = q3-q1
lower_lim = q1 - 1.5*iqr
upper_lim = q3 + 1.5*iqr

# %%
q1,q3,iqr
# Out:
# (3600.0, 6360.0, 2760.0)

# %%
lower_lim, upper_lim
# Out:
# (-540.0, 10500.0)

# %%
out_area = df[(df['area'] > upper_lim) | (df['area'] < lower_lim)]

# %%
out_area
# Out:
#        price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 7    9205000  16200         5          3        2      yes        no       no
# 10   9205000  13200         3          1        2      yes        no      yes
# 56   7343000  11440         4          1        2      yes        no      yes
# 64   7000000  11175         3          1        1      yes        no      yes
# 66   6930000  13200         2          1        1      yes        no      yes
# 69   6790000  12090         4          2        2      yes        no       no
# 125  5943000  15600         3          1        1      yes        no       no
# 129  5873000  11460         3          1        3      yes        no       no
# 186  5110000  11410         2          1        2      yes        no       no
# 191  5040000  10700         3          1        2      yes       yes      yes
# 211  4900000  12900         3          1        1      yes        no       no
# 403  3500000  12944         3          1        1      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 7                no              no        0       no      unfurnished
# 10               no             yes        2      yes        furnished
# 56               no              no        1      yes   semi-furnished
# 64               no             yes        1      yes        furnished
# 66              yes              no        1       no        furnished
# 69               no              no        2      yes        furnished
# 125              no             yes        2       no   semi-furnished
# 129              no              no        2      yes   semi-furnished
# 186              no              no        0      yes        furnished
# 191              no              no        0       no   semi-furnished
# 211              no              no        2       no        furnished
# 403              no              no        0       no      unfurnished

# %%
df.loc[df['area'] > upper_lim, 'area'] = upper_lim
df.loc[df['area'] < lower_lim, 'area'] = lower_lim

# %%
sns.boxplot(df['area'])
# Out:
# <Axes: ylabel='area'>

# %%
df.head()
# Out:
#      price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  9205000  7420         4          2        3      yes        no       no
# 1  9205000  8960         4          4        4      yes        no       no
# 2  9205000  9960         3          2        2      yes        no      yes
# 3  9205000  7500         4          2        2      yes        no      yes
# 4  9205000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df['mainroad'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
df['guestroom'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df['basement'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df['hotwaterheating'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df['airconditioning'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
df['prefarea'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
df['furnishingstatus'].unique()
# Out:
# array(['furnished', 'semi-furnished', 'unfurnished'], dtype=object)

# %%
le=LabelEncoder()

# %%
for col in ['mainroad', 'guestroom', 'basement', 'hotwaterheating',
            'airconditioning', 'prefarea', 'furnishingstatus']:
    df['le_' + col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#      price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  9205000  7420         4          2        3      yes        no       no
# 1  9205000  8960         4          4        4      yes        no       no
# 2  9205000  9960         3          2        2      yes        no      yes
# 3  9205000  7500         4          2        2      yes        no      yes
# 4  9205000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus  \
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished
#
#    le_mainroad  le_guestroom  le_basement  le_hotwaterheating  \
# 0            1             0            0                   0
# 1            1             0            0                   0
# 2            1             0            1                   0
# 3            1             0            1                   0
# 4            1             1            1                   0
#
#    le_airconditioning  le_prefarea  le_furnishingstatus
# 0                   1            1                    0
# 1                   1            0                    0
# 2                   0            1                    1
# 3                   1            1                    0
# 4                   1            0                    0

# %% [markdown]
# # **Feature Selection**

# %%
features = df[['area','bedrooms','bathrooms','stories','parking','le_mainroad','le_guestroom',
          'le_basement','le_hotwaterheating','le_airconditioning','le_prefarea','le_furnishingstatus']]

# %%
features
# Out:
#      area  bedrooms  bathrooms  stories  parking  le_mainroad  le_guestroom  \
# 0    7420         4          2        3        2            1             0
# 1    8960         4          4        4        3            1             0
# 2    9960         3          2        2        2            1             0
# 3    7500         4          2        2        3            1             0
# 4    7420         4          1        2        2            1             1
# ..    ...       ...        ...      ...      ...          ...           ...
# 540  3000         2          1        1        2            1             0
# 541  2400         3          1        1        0            0             0
# 542  3620         2          1        1        0            1             0
# 543  2910         3          1        1        0            0             0
# 544  3850         3          1        2        0            1             0
#
#      le_basement  le_hotwaterheating  le_airconditioning  le_prefarea  \
# 0              0                   0                   1            1
# 1              0                   0                   1            0
# 2              1                   0                   0            1
# 3              1                   0                   1            1
# 4              1                   0                   1            0
# ..           ...                 ...                 ...          ...
# 540            1                   0                   0            0
# 541            0                   0                   0            0
# 542            0                   0                   0            0
# 543            0                   0                   0            0
# 544            0                   0                   0            0
#
#      le_furnishingstatus
# 0                      0
# 1                      0
# 2                      1
# 3                      0
# 4                      0
# ..                   ...
# 540                    2
# 541                    1
# 542                    2
# 543                    0
# 544                    2
#
# [545 rows x 12 columns]

# %%
target = df['price']

# %%
target
# Out:
# 0      9205000
# 1      9205000
# 2      9205000
# 3      9205000
# 4      9205000
#         ...
# 540    1820000
# 541    1767150
# 542    1750000
# 543    1750000
# 544    1750000
# Name: price, Length: 545, dtype: int64

# %%
ss = StandardScaler()

# %%
ss_df = ss.fit_transform(features)

# %%
ss_df
# Out:
# array([[ 1.15658327,  1.40341936,  1.42181174, ...,  1.4726183 ,
#          1.80494113, -1.40628573],
#        [ 1.92506041,  1.40341936,  5.40580863, ...,  1.4726183 ,
#         -0.55403469, -1.40628573],
#        [ 2.42407154,  0.04727831,  1.42181174, ..., -0.67906259,
#          1.80494113, -0.09166185],
#        ...,
#        [-0.73965902, -1.30886273, -0.57018671, ..., -0.67906259,
#         -0.55403469,  1.22296203],
#        [-1.09395692,  0.04727831, -0.57018671, ..., -0.67906259,
#         -0.55403469, -1.40628573],
#        [-0.62488646,  0.04727831, -0.57018671, ..., -0.67906259,
#         -0.55403469,  1.22296203]])

# %% [markdown]
# # **Model Training**

# %%
xtrain, xtest, ytrain, ytest = train_test_split(ss_df, target, test_size=0.2, random_state=0)

# %%
xtrain.shape, xtest.shape, ytrain.shape, ytest.shape
# Out:
# ((436, 12), (109, 12), (436,), (109,))

# %% [markdown]
# # **Linear Regression**

# %%
lr = LinearRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
ypred=lr.predict(xtest)

# %%
ypred
# Out:
# array([ 4007877.99161288,  6111769.54373083,  4416326.43738446,
#         6699611.53480697,  2943502.43608678,  7056633.73850357,
#         3235970.36915839,  3174809.26516679,  3451885.0805991 ,
#         8196888.59261359,  6608123.2613851 ,  3832164.13420655,
#         3762225.48617292,  4686909.52618551,  4001110.99810013,
#         2075815.43276707,  4015046.34238242,  3709140.65976372,
#         3211561.43578158,  4583874.50697678,  5917579.69226888,
#         6479698.78379952,  4692607.58188371,  2766868.63191559,
#         5314695.45499359,  5679758.72218174,  5190723.68645495,
#         5463307.64568701,  5571046.87808072,  5774489.41604293,
#         3326992.07803354,  6242002.10838795,  6995078.3851952 ,
#         2995060.12670042,  4460123.50169055,  5016770.31899275,
#         4882658.2347299 ,  3654308.16004005,  3027008.98207943,
#         3987946.07880223,  7941403.20254504,  4917744.72722048,
#         6430838.8322824 ,  3635291.9636818 ,  3744407.95729454,
#         6299150.99619949,  4542892.75822322,  2829773.06408953,
#         4082871.79123597,  6345538.72461647,  3988749.88414317,
#         7025366.0108568 ,  2595499.32627253,  3018336.58698526,
#         3599843.14241644,  5111507.28010077,  7123749.00161748,
#         4061766.36529139,  2953169.11951371,  4449512.72609475,
#         5445606.60024965,  6655063.1025036 ,  3344791.36558026,
#         7124441.46521872,  2646874.30927679,  5018438.60437942,
#         6578134.07994944,  2632078.38262712,  3852107.03949326,
#         4940139.92972326,  4254600.74934414,  7184173.22177136,
#         5039400.38296391,  5964734.35683036,  4151253.57777972,
#         4508502.64138188,  3006092.12243956,  7465255.84094409,
#         2677118.56666063,  3651895.71266676,  4254600.74934414,
#         6116016.60495757,  5087646.93957309,  5491659.94005285,
#         3886052.50788506,  4118741.155685  ,  4736796.88229058,
#         5083331.68788518,  3922115.32338117,  4261963.16150913,
#         3377600.76297863,  5784867.16179051,  3201686.71248326,
#         3601492.80211154,  4405617.93608252, 10199670.73281975,
#         2966531.75808858,  6905502.97933756,  4443540.33772405,
#         4607762.35575234,  6513252.73901974,  3299959.72029225,
#         4575509.76815088,  3406833.24655005,  7241181.78492436,
#         5166654.16409519,  4060797.84582702,  5018320.34176765,
#         6118172.53792685])

# %%
ytest
# Out:
# 239    4585000
# 113    6083000
# 325    4007500
# 66     6930000
# 479    2940000
#         ...
# 76     6650000
# 132    5810000
# 311    4123000
# 464    3080000
# 155    5530000
# Name: price, Length: 109, dtype: int64

# %% [markdown]
# # **Model Evaluation**

# %%
r2_linear=r2_score(ytest,ypred)

# %%
r2_linear
# Out:
# 0.6258795720453351

# %% [markdown]
# # **Prediction**

# %%
index = 18
actual_index = ytest.index[index]

print(f"Actual Price: {ytest[actual_index]}")
print(f"Predicted Price: {ypred[index]}")
# Out:
# Actual Price: 3360000
# Predicted Price: 3211561.4357815823

# %% [markdown]
# # **Visualization**

# %%
plt.scatter(ytest, ypred)
plt.plot([min(ytest), max(ytest)], [min(ytest), max(ytest)], color='red', lw=2)
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Actual vs Predicted House Prices')
plt.show()
